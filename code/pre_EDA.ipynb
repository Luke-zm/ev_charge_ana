# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
q2_14 = pd.read_csv("../data/2014 EVCP use Q2.csv")

# %%
q2_14
# Out:
#     Charging event  User ID  CP ID  Connector  Start Date Start Time  \
# 0           261569  User 37  70204          1   6/30/2014      19:33
# 1           261146  User 37  70204          2   6/29/2014      16:06
# 2           260029  User 37  70204          2   6/25/2014      20:17
# 3           253159   User 4  70200          1  06/08/2014      13:54
# 4           250057  User 23  70204          1   5/30/2014      16:27
# 5           248161  User 34  70201          1   5/26/2014      13:29
# 6           247743  User 11  70200          2   5/24/2014      10:31
# 7           243750  User 17  70202          1  05/12/2014      15:55
# 8           243232  User 11  70202          1  05/10/2014      10:18
# 9           236159  User 15  70204          2   4/18/2014      08:41
# 10          234600  User 15  70204          2  04/12/2014      11:55
# 11          233978  User 15  70204          2  04/10/2014      07:41
#
#       End Date End Time  Total kWh                     Site  \
# ...

# %%
# Function to map User ID into UID of more digits
# Include yr, Q and

# %%
q34_2014 = pd.read_csv("../data/2014 EVCP use Q3 and Q4.csv")
q34_2014
# Out:
#     Charging event   User ID  CP ID  Connector  Start Date Start Time  \
# 0           383322   User 31  70206          2  12/31/2014      11:25
# 1           383031  User 635  70206          1  12/30/2014      13:58
# 2           381777   User 38  70201          2  12/27/2014      18:13
# 3           380951  User 629  70208          1  12/24/2014      11:37
# 4           377470  User 626  70204          2  12/18/2014      09:29
# ..             ...       ...    ...        ...         ...        ...
# 73          278517   User 42  70203          1  08/12/2014      08:36
# 74          274698    User 9  70204          1  08/05/2014      10:38
# 75          270653   User 37  70204          1   7/24/2014      20:09
# 76          266514   User 37  70204          1   7/13/2014      11:01
# 77          264599    User 2  70205          1  07/07/2014      12:27
#
#       End Date End Time  Total kWh                       Site  \
# 0   12/31/2014    11:35       0.57  Elland Road Park and Ride
# ...

# %%
q12_2015 = pd.read_csv("../data/2015 EVCP use Q1 and Q2.csv")

# %%
q12_2015
# Out:
#      Charging event   User ID  CP ID  Connector  Start Date Start Time  \
# 0            384954  User 636  70208          1  01/05/2015      09:03
# 1            385563  User 628  70208          1  01/06/2015      09:04
# 2            385578  User 636  70205          1  01/06/2015      09:35
# 3            386323  User 628  70208          1  01/07/2015      09:02
# 4            387054   User 44  70204          2  01/08/2015      08:10
# ..              ...       ...    ...        ...         ...        ...
# 213         1078855   User 38  70206          1   6/29/2015      09:13
# 214         1078859   User 38  70206          2   6/29/2015      09:16
# 215         1078864   User 38  70206          1   6/29/2015      09:20
# 216         1080286  User 628  70206          2   6/30/2015      08:44
# 217         1080405   User 38  70208          1   6/30/2015      09:34
#
#        End Date End Time  Total kWh                       Site  \
# ...

# %%
q3_2020 = pd.read_csv("../data/2020 EVCP use Q3.csv")

# %%
q3_2020
# Out:
#      Charging event   User ID  CP ID  Connector  Start Date Start Time  \
# 0           9953306  User 380  70204          1  01/07/2020      07:48
# 1           9953495  User 372  70200          2  01/07/2020      08:54
# 2           9953572  User 324  51467          2  01/07/2020      09:21
# 3           9954480  User 621  70204          2  01/07/2020      14:47
# 4           9954752  User 624  51467          2  01/07/2020      16:22
# ..              ...       ...    ...        ...         ...        ...
# 940        10456270  User 613  70204          2  30/09/2020      18:05
# 941        10456289  User 618  70202          1  30/09/2020      18:08
# 942        10456536  User 624  51467          1  30/09/2020      19:09
# 943        10456839  User 621  70200          2  30/09/2020      21:30
# 944        10456842  User 615  70202          2  30/09/2020      21:31
#
#        End Date End Time  Total kWh                     Site  \
# ...

# %%
q1_2021 = pd.read_csv("../data/2021 EVCP use Q1.csv")

# %%
q1_2021
# Out:
#       Charging event Unique User ID  CP ID  Connector  Start Date Start Time  \
# 0           12654900       User 613  81028          2  31/03/2021      21:07
# 1           12653764      User 1132  70201          1  31/03/2021      19:47
# 2           12652572       User 624  70200          2  31/03/2021      18:29
# 3           12651038       User 623  81028          1  31/03/2021      16:52
# 4           12650838       User 149  81028          2  31/03/2021      16:41
# ...              ...            ...    ...        ...         ...        ...
# 1006        10932488      User 1115  51467          2  03/01/2021      07:11
# 1007        10932167       User 621  70202          1  02/01/2021      20:08
# 1008        10932165       User 613  70204          1  02/01/2021      20:08
# 1009        10930312       User 520  51468          2  02/01/2021      07:39
# 1010        10928620       User 304  51468          2  01/01/2021      07:50
#
# ...
